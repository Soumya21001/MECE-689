# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque
from gymnasium.envs.toy_text.frozen_lake import generate_random_map
import time

# %%
# Create the FrozenLake environment 
random.seed(21)
np.random.seed(21)
torch.manual_seed(21)
env = gym.make("FrozenLake-v1",render_mode='human',desc=generate_random_map(size=5), is_slippery = False)  # Disable randomness for simplicity
state_space = env.observation_space.n
action_space = env.action_space.n
env.action_space.seed(21)
env.observation_space.seed(21)  # Seed the observation space
env.reset(seed=21)


# Parameters
gamma = 0.99
epsilon = 1.0
epsilon_min = 0.1
epsilon_decay = 0.999
learning_rate = 0.1
batch_size = 64
buffer_size = 10000
target_update_freq = 10
num_episodes = 500

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)  #Sample a batch of transitions uniformly
        states, actions, rewards, next_states, dones = zip(*batch)
        return np.array(states), np.array(actions), np.array(rewards), np.array(next_states), np.array(dones)

    def __len__(self):
        return len(self.buffer)

# %%
# Replay buffer
replay_buffer = ReplayBuffer(buffer_size)

# %%
# Convert state to one-hot encoding
def one_hot_state(state, num_states):
    one_hot = np.zeros(num_states)
    one_hot[state] = 1
    return one_hot

# %%
def custom_reward(state, action, reward, done, goal_state, visited_states):
    if int(state.argmax()) == int(goal_state.argmax()):
        return reward+100  # High reward for reaching the goal
    elif done:
        return -20  # Heavy penalty for falling
    if tuple(state) in visited_states:
        return reward-5  # Penalty for revisiting a state
    else:
        return 1

# %%
# Neural Network for DQN
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, output_dim))
    
    def forward(self, x):
        return self.fc(x)

# %%
policy_net = DQN(state_space, action_space)  #neural network that approximates the Q-value
target_net = DQN(state_space, action_space)  # provides fixed Q-value targets for several steps
target_net.load_state_dict(policy_net.state_dict())
optimizer = optim.Adam(policy_net.parameters(), lr=learning_rate)

# %%
#Training Loop
total_rewards = []
success_count = 0
steps_to_goal = []

for episode in range(num_episodes):
    state, _ = env.reset()
    state = one_hot_state(state, state_space)
    done = False
    total_reward = 0
    step_count = 0
    goal_state = state_space - 1
    goal_state = one_hot_state(goal_state, state_space)
    visited_states = set()

    while not done:
        if random.random() < epsilon:
            action = random.choice(range(action_space))  # Exploration
        else:
            with torch.no_grad():
                action = torch.argmax(policy_net(torch.tensor(state, dtype=torch.float32))).item()  # Exploitation

        next_state, reward, done, _, _ = env.step(action)
        next_state = one_hot_state(next_state, state_space)

        reward = custom_reward(next_state, action, reward, done, goal_state, visited_states)
        total_reward += reward
        step_count += 1

        visited_states.add(tuple(next_state))  #updating visiting states for checking looping

        replay_buffer.add((state, action, reward, next_state, done))
        state = next_state

        # Training Q-Network
        if len(replay_buffer) > batch_size:
            states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)

            states = torch.tensor(states, dtype=torch.float32)
            actions = torch.tensor(actions, dtype=torch.long)
            rewards = torch.tensor(rewards, dtype=torch.float32)
            next_states = torch.tensor(next_states, dtype=torch.float32)
            dones = torch.tensor(dones, dtype=torch.float32)

            # Computing target Q-values
            with torch.no_grad():
                target_q_values = rewards + gamma * (1 - dones) * torch.max(target_net(next_states), dim=1)[0]

            current_q_values = policy_net(states).gather(1, actions.unsqueeze(1)).squeeze(1)

            loss = nn.MSELoss()(current_q_values, target_q_values)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    epsilon = max(epsilon * epsilon_decay, epsilon_min)

    # Updating target network every 10 episodes
    if episode % target_update_freq == 0:
        target_net.load_state_dict(policy_net.state_dict())

    total_rewards.append(total_reward)
    if done and int(state.argmax()) == int(goal_state.argmax()):
        success_count += 1
        steps_to_goal.append(step_count)

    print(f"Episode {episode + 1}, Total Reward: {total_reward}, Steps: {step_count}, Goal Reached: {'Yes' if done and int(state.argmax()) == int(goal_state.argmax()) else 'No'}")

avg_reward = np.mean(total_rewards)
success_rate = (success_count / num_episodes) * 100
avg_steps_to_goal = np.mean(steps_to_goal) if steps_to_goal else float('inf')

print("\n--- Training Metrics ---")
print(f"Average Reward: {avg_reward:.2f}")
print(f"Success Rate: {success_rate:.2f}%")
print(f"Average Steps to Goal (for successful episodes): {avg_steps_to_goal:.2f}")
print("------------------------")

# Saving the trained model
torch.save(policy_net.state_dict(), "model/DQN_policy_net.pth")
print("Training complete. Model saved.")
# Out:
# Episode 1, Total Reward: -76.0, Steps: 17, Goal Reached: No
# Episode 2, Total Reward: -71.0, Steps: 16, Goal Reached: No
# Episode 3, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 4, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 5, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 6, Total Reward: -46.0, Steps: 11, Goal Reached: No
# Episode 7, Total Reward: -17, Steps: 4, Goal Reached: No
# Episode 8, Total Reward: -33.0, Steps: 6, Goal Reached: No
# Episode 9, Total Reward: -29.0, Steps: 4, Goal Reached: No
# Episode 10, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 11, Total Reward: -40.0, Steps: 11, Goal Reached: No
# Episode 12, Total Reward: -75.0, Steps: 18, Goal Reached: No
# Episode 13, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 14, Total Reward: -30.0, Steps: 15, Goal Reached: No
# Episode 15, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 16, Total Reward: -48.0, Steps: 9, Goal Reached: No
# Episode 17, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 18, Total Reward: -33.0, Steps: 6, Goal Reached: No
# Episode 19, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 20, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 21, Total Reward: -47.0, Steps: 10, Goal Reached: No
# Episode 22, Total Reward: -114.0, Steps: 27, Goal Reached: No
# Episode 23, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 24, Total Reward: -160.0, Steps: 41, Goal Reached: No
# Episode 25, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 26, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 27, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 28, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 29, Total Reward: -31.0, Steps: 8, Goal Reached: No
# Episode 30, Total Reward: -17, Steps: 4, Goal Reached: No
# Episode 31, Total Reward: -229.0, Steps: 62, Goal Reached: No
# Episode 32, Total Reward: -81.0, Steps: 18, Goal Reached: No
# Episode 33, Total Reward: -85.0, Steps: 20, Goal Reached: No
# Episode 34, Total Reward: -22.0, Steps: 5, Goal Reached: No
# Episode 35, Total Reward: -38.0, Steps: 7, Goal Reached: No
# Episode 36, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 37, Total Reward: -48.0, Steps: 9, Goal Reached: No
# Episode 38, Total Reward: -23.0, Steps: 10, Goal Reached: No
# Episode 39, Total Reward: -57.0, Steps: 18, Goal Reached: No
# Episode 40, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 41, Total Reward: 22.0, Steps: 30, Goal Reached: Yes
# Episode 42, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 43, Total Reward: 24.0, Steps: 26, Goal Reached: Yes
# Episode 44, Total Reward: -31.0, Steps: 8, Goal Reached: No
# Episode 45, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 46, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 47, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 48, Total Reward: -30.0, Steps: 9, Goal Reached: No
# Episode 49, Total Reward: -107.0, Steps: 28, Goal Reached: No
# Episode 50, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 51, Total Reward: -37.0, Steps: 8, Goal Reached: No
# Episode 52, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 53, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 54, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 55, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 56, Total Reward: -60.0, Steps: 15, Goal Reached: No
# Episode 57, Total Reward: -63.0, Steps: 12, Goal Reached: No
# Episode 58, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode
Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 431, Total Reward: -43.0, Steps: 8, Goal Reached: No
# Episode 432, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 433, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 434, Total Reward: -14, Steps: 7, Goal Reached: No
# Episode 435, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 436, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 437, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 438, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 439, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 440, Total Reward: -37.0, Steps: 8, Goal Reached: No
# Episode 441, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 442, Total Reward: -34.0, Steps: 5, Goal Reached: No
# Episode 443, Total Reward: -172.0, Steps: 41, Goal Reached: No
# Episode 444, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 445, Total Reward: -48.0, Steps: 9, Goal Reached: No
# Episode 446, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 447, Total Reward: -17, Steps: 4, Goal Reached: No
# Episode 448, Total Reward: -60.0, Steps: 21, Goal Reached: No
# Episode 449, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 450, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 451, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 452, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 453, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 454, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 455, Total Reward: 108.0, Steps: 8, Goal Reached: Yes
# Episode 456, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 457, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 458, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 459, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 460, Total Reward: -22.0, Steps: 5, Goal Reached: No
# Episode 461, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 462, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 463, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 464, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 465, Total Reward: -32.0, Steps: 7, Goal Reached: No
# Episode 466, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 467, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 468, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 469, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 470, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 471, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 472, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 473, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 474, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 475, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 476, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 477, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 478, Total Reward: 74.0, Steps: 16, Goal Reached: Yes
# Episode 479, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 480, Total Reward: -29.0, Steps: 4, Goal Reached: No
# Episode 481, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 482, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 483, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 484, Total Reward: -31.0, Steps: 8, Goal Reached: No
# Episode 485, Total Reward: -24.0, Steps: 3, Goal Reached: No
# Episode 486, Total Reward: -18, Steps: 3, Goal Reached: No
# Episode 487, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 488, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 489, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 490, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 491, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 492, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 493, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 494, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 495, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 496, Total Reward: -28.0, Steps: 5, Goal Reached: No
# Episode 497, Total Reward: -19, Steps: 2, Goal Reached: No
# Episode 498, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 499, Total Reward: -23.0, Steps: 4, Goal Reached: No
# Episode 500, Total Reward: -18, Steps: 3, Goal Reached: No
#
# --- Training Metrics ---
# Average Reward: -27.67
# Success Rate: 2.80%
# Average Steps to Goal (for successful episodes): 19.21
# ------------------------
# Training complete. Model saved.

# %%
# Testing the trained policy
def test_dqn(policy_net, env, num_test_episodes=100):
    total_rewards = []
    success_count = 0
    goal_state = state_space - 1  # Define the goal state
    goal_state = one_hot_state(goal_state,state_space)

    # Load trained policy net
    policy_net.load_state_dict(torch.load("model/DQN_policy_net.pth"))
    policy_net.eval()

    for episode in range(num_test_episodes):
        state, _ = env.reset()
        state = one_hot_state(state, state_space)
        done = False
        episode_reward = 0
        visited_states = set()  # Track visited states
        trajectory = []  

        while not done:
                trajectory.append(state.argmax())  # Log the agent's current state
                
                if random.random() < 0.1:  # 10% chance to explore
                    action = random.choice(range(action_space))
                else:
                    with torch.no_grad():
                        action = torch.argmax(policy_net(torch.tensor(state, dtype=torch.float32))).item()
            
            # Take a step in the environment
                next_state, reward, done, _, _ = env.step(action)
                next_state = one_hot_state(next_state, state_space)
                
                reward = custom_reward(next_state, action, reward, done, goal_state,visited_states)
                episode_reward += reward
                state = next_state

                total_rewards.append(episode_reward)

        # Checking if the goal state was reached
        if done and int(state.argmax()) == int(goal_state.argmax()):
            success_count += 1
            

        print(f"Test Episode {episode + 1}: Reward = {total_reward:.2f}, Steps = {step_count}, Goal Reached: {'Yes' if done and int(state.argmax()) == int(goal_state.argmax()) else 'No'}")

    avg_reward = np.mean(total_rewards)
    success_rate = (success_count / num_test_episodes) * 100
    avg_steps_test = np.mean(steps_to_goal) if steps_to_goal else float('inf')

    print("\n--- Testing Metrics ---")
    print(f"Average Reward: {avg_reward:.2f}")
    print(f"Success Rate: {success_rate:.2f}%")
    print(f"Average Steps to Goal (for successful episodes): {avg_steps_test:.2f}")
    print("------------------------")

# %%
# Run the test
print("Testing the trained policy...")
test_dqn(policy_net, env, num_test_episodes=200)
# Out:
# Testing the trained policy...
# C:\Users\Soumya Taneja\AppData\Local\Temp\ipykernel_5432\3626404.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   policy_net.load_state_dict(torch.load("DQN_policy_net.pth"))
# Test Episode 1: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 2: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 3: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 4: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 5: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 6: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 7: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 8: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 9: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 10: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 11: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 12: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 13: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 14: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 15: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 16: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 17: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 18: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 19: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 20: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 21: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 22: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 23: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 24: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 25: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 26: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 27: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 28: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 29: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 30: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 31: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 32: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 33: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 34: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 35: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 36: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 37: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 38: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 39: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 40: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 41: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 42: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 43: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 44: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 45: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 46: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 47: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 48: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 49: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 50: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 51: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 52: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 53: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 54: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 55: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 56: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 57: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 58: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 59: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 60: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 61: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 62: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 63: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 64: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 65: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 66: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 67: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 68: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 69: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 70: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 71: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 72: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 73: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 74: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 75: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 76: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 77: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 78: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 79: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 80: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 81: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 82: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 83: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 84: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 85: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 86: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 87: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 88: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 89: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 90: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 91: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 92: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 93: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 94: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 95: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 96: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 97: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 98: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 99: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 100: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 101: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 102: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 103: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 104: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 105: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 106: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 107: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 108: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 109: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 110: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 111: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 112: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 113: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 114: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 115: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 116: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 117: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 118: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 119: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 120: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 121: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 122: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 123: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 124: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 125: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 126: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 127: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 128: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 129: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 130: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 131: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 132: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 133: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 134: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 135: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 136: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 137: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 138: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 139: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 140: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 141: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 142: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 143: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 144: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 145: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 146: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 147: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 148: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 149: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 150: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 151: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 152: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 153: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 154: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 155: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 156: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 157: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 158: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 159: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 160: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 161: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 162: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 163: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 164: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 165: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 166: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 167: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 168: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 169: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 170: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 171: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 172: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 173: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 174: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 175: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 176: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 177: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 178: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 179: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 180: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 181: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 182: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 183: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 184: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 185: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 186: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 187: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 188: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 189: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 190: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 191: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 192: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 193: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 194: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 195: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 196: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 197: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 198: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 199: Reward = -18.00, Steps = 3, Goal Reached: No
# Test Episode 200: Reward = -18.00, Steps = 3, Goal Reached: No
#
# --- Testing Metrics ---
# Average Reward: -8.17
# Success Rate: 0.00%
# Average Steps to Goal (for successful episodes): 19.21
# ------------------------
